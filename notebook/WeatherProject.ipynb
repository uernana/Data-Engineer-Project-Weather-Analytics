# %% [markdown]
# ## **PROJECT BLUEPRINT**

# %% [markdown]
# **Project Goal:**
#
# + Build an end-to-end ETL pipeline that:
#
#     + Extracts weather data from OpenWeather API
#
#     + Transforms the raw data (cleaning, converting units, formatting)
#
#     + Loads the cleaned data into PostgreSQL
#
# + Automates daily batch ingestion using cron / scheduled tasks
#
# + Visualizes current weather data + forecast weather data using BI Tool

# %% [markdown]
#            ┌──────────────────┐
#            │ OpenWeather API  │
#            └────────┬─────────┘
#                     │ (JSON)
#                     ▼
#           ┌────────────────────┐
#           │ Python ETL Script  │
#           │ (requests, pandas) │
#           └───────┬────────────┘
#                   │ cleaned data
#                   ▼
#         ┌────────────────────────┐
#         │   PostgreSQL Database  │
#         └────────┬───────────────┘
#                  │
#                  ▼
#        BI Tools / Dashboards

# %% [markdown]
# **Set up:** Python environment, PostgreSQL (create database, user, grant privillege..)

# %% [markdown]
# **Table 1:** Weather_current:
#
# | Column      | Type      | Description        |
# | ----------- | --------- | ------------------ |
# | id          | SERIAL PK | Unique row         |
# | city        | VARCHAR   | City name          |
# | temp_c      | FLOAT     | Celsius            |
# |feels_like   |FLOAT      | Celcius            |
# |temps_min    |FLOAT      | Celcius            |
# |temps_max    |FLOAT      | Celcius            |
# |pressure     |FLOAT      |                    |
# |grnd_level   |FLOAT      | Atmospheric pressure on the ground level |
# | humidity    | INT       | Humidity %         |
# | wind_speed  | FLOAT     | m/s                |
# | description | VARCHAR   | Cloudy, Rainy, etc |
# | dt          | TIMESTAMP | API timestamp      |
# | created_at  | TIMESTAMP | Insertion time     |
# |sunrise      |TIMESTAMP  | API timestamp      |
# |sunset       |TIMESTAMP  |API timestamp       |

# %% [markdown]
# **Table 2:** Weather_forecast
#
# | Column      | Type      | Description        |
# | ----------- | --------- | ------------------ |
# | id          | SERIAL PK | Unique row         |
# | city        | VARCHAR   | City name          |
# | temp_c      | FLOAT     | Celsius            |
# |feels_like   |FLOAT      | Celcius            |
# |temps_min    |FLOAT      | Celcius            |
# |temps_max    |FLOAT      | Celcius            |
# |pressure     |FLOAT      |                    |
# |grnd_level   |FLOAT      | Atmospheric pressure on the ground level |
# | humidity    | INT       | Humidity %         |
# | wind_speed  | FLOAT     | m/s                |
# | description | VARCHAR   | Cloudy, Rainy, etc |
# | dt          | TIMESTAMP | API timestamp      |
# | created_at  | TIMESTAMP | Insertion time     |
# |sunrise      |TIMESTAMP  | API timestamp      |
# |sunset       |TIMESTAMP  |API timestamp       |

# %% [markdown]
# **Table 3:** City information
#
# | Column      | Type      | Description        |
# | ----------- | --------- | ------------------ |
# | id          | SERIAL PK | Unique row         |
# | city        | VARCHAR   | City name          |
# | country     | VARCHAR   | Country code       |
# | lat         | FLOAT     |                    |
# | lon         | FLOAT     |                    |
# | timezone    | TIMESTAMP |                    |
# |             |with zone  | API timestamp      |
# | population  | INT       |                    |

# %% [markdown]
# ## **Extract Phase**

# %%
import requests
import os

API_KEY = "57c2842bfac979c9a3e8b4297d85185d"

def fetch_weather(city):
    url = f"https://api.openweathermap.org/data/2.5/weather?q={city}&appid={API_KEY}&lang=vi"

    try:
        response = requests.get(url)
        data = response.json()
        return data
    except Exception as e:
        print(f"Exception fetching {city}: {e}")
        return None
cities = [
    "Hanoi", "Sapa", "Ha Long", "Hai Duong",            # North
    "Hue", "Vinh", "Da Nang", "Quy Nhon", "Nha Trang", "Da Lat",   # Central
    "Ho Chi Minh", "Binh Duong", "Can Tho", "Vinh Long"            # South
]

# Loop through each city and print weather
for c in cities:
    result = fetch_weather(c)
    print(f"\n=== {c} ===")
    print(result)
# Out:
# === Hanoi ===
# {'coord': {'lon': 105.8412, 'lat': 21.0245}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'mây rải rác', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': 295.15, 'feels_like': 294.37, 'temp_min': 295.15, 'temp_max': 295.15, 'pressure': 1021, 'humidity': 37, 'sea_level': 1021, 'grnd_level': 1020}, 'visibility': 10000, 'wind': {'speed': 4.12, 'deg': 355, 'gust': 5.89}, 'clouds': {'all': 34}, 'dt': 1764130277, 'sys': {'type': 1, 'id': 9308, 'country': 'VN', 'sunrise': 1764112440, 'sunset': 1764152047}, 'timezone': 25200, 'id': 1581130, 'name': 'Hà Nội', 'cod': 200}
#
# === Sapa ===
# {'coord': {'lon': 120.3241, 'lat': 5.1544}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'mưa nhẹ', 'icon': '10d'}], 'base': 'stations', 'main': {'temp': 302.7, 'feels_like': 307.56, 'temp_min': 302.7, 'temp_max': 302.7, 'pressure': 1007, 'humidity': 72, 'sea_level': 1007, 'grnd_level': 1006}, 'visibility': 10000, 'wind': {'speed': 4.69, 'deg': 186, 'gust': 6.43}, 'rain': {'1h': 0.11}, 'clouds': {'all': 99}, 'dt': 1764130386, 'sys': {'country': 'PH', 'sunrise': 1764107427, 'sunset': 1764150107}, 'timezone': 28800, 'id': 1687343, 'name': 'Sapa', 'cod': 200}
#
# === Ha Long ===
# {'coord': {'lon': 107.08, 'lat': 20.9511}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'mây cụm', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 296.4, 'feels_like': 295.77, 'temp_min': 296.4, 'temp_max': 296.4, 'pressure': 1020, 'humidity': 38, 'sea_level': 1020, 'grnd_level': 1011}, 'visibility': 10000, 'wind': {'speed': 0.99, 'deg': 140, 'gust': 0.87}, 'clouds': {'all': 70}, 'dt': 1764130173, 'sys': {'country': 'VN', 'sunrise': 1764112135, 'sunset': 1764151758}, 'timezone': 25200, 'id': 1580410, 'name': 'Thành Phố Hạ Long', 'cod': 200}
#
# === Hai Duong ===
# {'coord': {'lon': 106.3167, 'lat': 20.9333}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'mây rải rác', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': 296.71, 'feels_like': 296.11, 'temp_min': 296.71, 'temp_max': 296.71, 'pressure': 1021, 'humidity': 38, 'sea_level': 1021, 'grnd_level': 1020}, 'visibility': 10000, 'wind': {'speed': 4.13, 'deg': 1, 'gust': 4.43}, 'clouds': {'all': 49}, 'dt': 1764130215, 'sys': {'country': 'VN', 'sunrise': 1764112316, 'sunset': 1764151943}, 'timezone': 25200, 'id': 1581326, 'name': 'Thành Phố Hải Dương', 'cod': 200}
#
# === Hue ===
# {'coord': {'lon': 107.6, 'lat': 16.4667}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'mưa nhẹ', 'icon': '10d'}], 'base': 'stations', 'main': {'temp': 294.21, 'feels_like': 294.67, 'temp_min': 294.21, 'temp_max': 294.21, 'pressure': 1018, 'humidity': 88, 'sea_level': 1018, 'grnd_level': 1016}, 'visibility': 10000, 'wind': {'speed': 5.14, 'deg': 310}, 'rain': {'1h': 0.47}, 'clouds': {'all': 75}, 'dt': 1764130369, 'sys': {'type': 1, 'id': 9310, 'country': 'VN', 'sunrise': 1764111554, 'sunset': 1764152089}, 'timezone': 25200, 'id': 1580240, 'name': 'Huế', 'cod': 200}
#
# === Vinh ===
# {'coord': {'lon': 105.6667, 'lat': 18.6667}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'mây thưa', 'icon': '02d'}], 'base': 'stations', 'main': {'temp': 294.77, 'feels_like': 294.55, 'temp_min': 294.77, 'temp_max': 294.77, 'pressure': 1020, 'humidity': 60, 'sea_level': 1020, 'grnd_level': 1019}, 'visibility': 10000, 'wind': {'speed': 2.96, 'deg': 359, 'gust': 3.74}, 'clouds': {'all': 24}, 'dt': 1764130387, 'sys': {'country': 'VN', 'sunrise': 1764112239, 'sunset': 1764152332}, 'timezone': 25200, 'id': 1562798, 'name': 'Vinh', 'cod': 200}
#
# === Da Nang ===
# {'coord': {'lon': 108.2208, 'lat': 16.0678}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'mây rải rác', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': 297.14, 'feels_like': 297.5, 'temp_min': 297.14, 'temp_max': 297.14, 'pressure': 1017, 'humidity': 73, 'sea_level': 1017, 'grnd_level': 1013}, 'visibility': 10000, 'wind': {'speed': 4.63, 'deg': 360}, 'clouds': {'all': 40}, 'dt': 1764130196, 'sys': {'type': 1, 'id': 9306, 'country': 'VN', 'sunrise': 1764111366, 'sunset': 1764151979}, 'timezone': 25200, 'id': 1583992, 'name': 'Đà Nẵng', 'cod': 200}
#
# === Quy Nhon ===
# {'coord': {'lon': 109.2333, 'lat': 13.7667}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'mưa nhẹ', 'icon': '10d'}], 'base': 'stations', 'main': {'temp': 297.68, 'feels_like': 298.3, 'temp_min': 297.68, 'temp_max': 297.68, 'pressure': 1014, 'humidity': 81, 'sea_level': 1014, 'grnd_level': 1007}, 'visibility': 10000, 'wind': {'speed': 10.86, 'deg': 1, 'gust': 14.45}, 'rain': {'1h': 0.27}, 'clouds': {'all': 99}, 'dt': 1764130388, 'sys': {'country': 'VN', 'sunrise': 1764110898, 'sunset': 1764151960}, 'timezone': 25200, 'id': 1568574, 'name': 'Quy Nhơn', 'cod': 200}
#
# === Nha Trang ===
# {'coord': {'lon': 109.1833, 'lat': 12.25}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'mây đen u ám', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 302.15, 'feels_like': 304.34, 'temp_min': 302.15, 'temp_max': 302.15, 'pressure': 1012, 'humidity': 61, 'sea_level': 1012, 'grnd_level': 1004}, 'visibility': 10000, 'wind': {'speed': 5.94, 'deg': 352, 'gust': 10.07}, 'clouds': {'all': 100}, 'dt': 1764130358, 'sys': {'type': 1, 'id': 9304, 'country': 'VN', 'sunrise': 1764110765, 'sunset': 1764152118}, 'timezone': 25200, 'id': 1572151, 'name': 'Nha Trang', 'cod': 200}
#
# === Da Lat ===
# {'coord': {'lon': 108.4419, 'lat': 11.9465}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'mây đen u ám', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 293.23, 'feels_like': 292.78, 'temp_min': 293.23, 'temp_max': 293.23, 'pressure': 1012, 'humidity': 57, 'sea_level': 1012, 'grnd_level': 856}, 'visibility': 10000, 'wind': {'speed': 2.84, 'deg': 48, 'gust': 5.04}, 'clouds': {'all': 86}, 'dt': 1764130221, 'sys': {'country': 'VN', 'sunrise': 1764110914, 'sunset': 1764152325}, 'timezone': 25200, 'id': 1584071, 'name': 'Ðà Lạt', 'cod': 200}
#
# === Ho Chi Minh ===
# {'coord': {'lon': 106.6667, 'lat': 10.75}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'bầu trời quang đãng', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 303.19, 'feels_like': 306.47, 'temp_min': 303.16, 'temp_max': 303.19, 'pressure': 1009, 'humidity': 62, 'sea_level': 1009, 'grnd_level': 1009}, 'visibility': 10000, 'wind': {'speed': 2.06, 'deg': 10}, 'clouds': {'all': 0}, 'dt': 1764130379, 'sys': {'type': 2, 'id': 2093009, 'country': 'VN', 'sunrise': 1764111226, 'sunset': 1764152864}, 'timezone': 25200, 'id': 1566083, 'name': 'Thành phố Hồ Chí Minh', 'cod': 200}
#
# === Binh Duong ===
# {'coord': {'lon': 109.0797, 'lat': 14.2972}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'mây đen u ám', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 297.54, 'feels_like': 298.07, 'temp_min': 297.54, 'temp_max': 297.54, 'pressure': 1015, 'humidity': 78, 'sea_level': 1015, 'grnd_level': 1005}, 'visibility': 10000, 'wind': {'speed': 8.89, 'deg': 4, 'gust': 13.84}, 'clouds': {'all': 85}, 'dt': 1764130159, 'sys': {'country': 'VN', 'sunrise': 1764110986, 'sunset': 1764151946}, 'timezone': 25200, 'id': 1587871, 'name': 'Binh Duong', 'cod': 200}
#
# === Can Tho ===
# {'coord': {'lon': 105.7833, 'lat': 10.0333}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'mây thưa', 'icon': '02d'}], 'base': 'stations', 'main': {'temp': 301.14, 'feels_like': 303.16, 'temp_min': 301.14, 'temp_max': 301.14, 'pressure': 1010, 'humidity': 65, 'sea_level': 1010, 'grnd_level': 1010}, 'visibility': 10000, 'wind': {'speed': 3.09, 'deg': 340}, 'clouds': {'all': 20}, 'dt': 1764130233, 'sys': {'type': 1, 'id': 9305, 'country': 'VN', 'sunrise': 1764111371, 'sunset': 1764153144}, 'timezone': 25200, 'id': 1586203, 'name': 'Cần Thơ', 'cod': 200}
#
# === Vinh Long ===
# {'coord': {'lon': 105.9667, 'lat': 10.25}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'mây đen u ám', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 301.11, 'feels_like': 303.36, 'temp_min': 301.11, 'temp_max': 301.11, 'pressure': 1010, 'humidity': 67, 'sea_level': 1010, 'grnd_level': 1010}, 'visibility': 10000, 'wind': {'speed': 3.31, 'deg': 350, 'gust': 3.52}, 'clouds': {'all': 100}, 'dt': 1764130390, 'sys': {'country': 'VN', 'sunrise': 1764111347, 'sunset': 1764153080}, 'timezone': 25200, 'id': 1562693, 'name': 'Vinh Long', 'cod': 200}

# %%
import requests
import os
import pandas as pd

def fetch_weather(city):
    url = f"https://api.openweathermap.org/data/2.5/weather?q={city}&appid={API_KEY}&units=metric&lang=vi"

    try:
        response = requests.get(url)
        data = response.json()

        # Check if response is OK
        if data.get("cod") != 200:
            print(f"Error fetching {city}: {data.get('message')}")
            return None

        event = {
            "coord_lon": data['coord']['lon'],
            "coord_lat": data['coord']['lat'],

            "weather_id": data['weather'][0]['id'],
            "weather_main": data['weather'][0]['main'],
            "description": data['weather'][0]['description'],
            "weather_icon": data['weather'][0]['icon'],

            "base": data.get('base'),

            "temp": data['main']['temp'],
            "feels_like": data['main']['feels_like'],
            "temp_min": data['main']['temp_min'],
            "temp_max": data['main']['temp_max'],
            "pressure": data['main']['pressure'],
            "humidity": data['main']['humidity'],

            "visibility": data.get('visibility'),

            "wind_speed": data['wind']['speed'],
            "wind_deg": data['wind']['deg'],
            "wind_gust": data['wind'].get('gust'),

            "clouds_all": data['clouds']['all'],

            "dt": data['dt'],

            "country": data['sys']['country'],
            "sunrise": data['sys']['sunrise'],
            "sunset": data['sys']['sunset'],

            "timezone": data['timezone'],
            "city_id": data['id'],
            "city_name": data['name']
        }

        df_weather = pd.DataFrame([event])  # wrap in list to create DataFrame
        return df_weather

    except Exception as e:
        print(f"Exception fetching {city}: {e}")
        return None

cities = [
    "Hanoi", "Sapa", "Ha Long", "Hai Duong",            # North
    "Hue", "Vinh", "Da Nang", "Quy Nhon", "Nha Trang", "Da Lat",   # Central
    "Ho Chi Minh", "Binh Duong", "Can Tho", "Vinh Long"            # South
]

# Fetch weather for all cities and combine
df_current = pd.concat([fetch_weather(c) for c in cities if fetch_weather(c) is not None], ignore_index=True)

print(df_current.head())
# Out:
#    coord_lon  coord_lat  weather_id weather_main  description weather_icon  \
# 0   105.8412    21.0245         802       Clouds  mây rải rác          03d
# 1   120.3241     5.1544         500         Rain      mưa nhẹ          10d
# 2   107.0800    20.9511         803       Clouds      mây cụm          04d
# 3   106.3167    20.9333         802       Clouds  mây rải rác          03d
# 4   107.6000    16.4667         803       Clouds      mây cụm          04d
#
#        base   temp  feels_like  temp_min  ...  wind_deg  wind_gust  \
# 0  stations  22.00       21.22     22.00  ...       355       5.89
# 1  stations  29.55       34.41     29.55  ...       186       6.43
# 2  stations  23.25       22.62     23.25  ...       140       0.87
# 3  stations  23.56       22.96     23.56  ...         1       4.43
# 4  stations  21.06       21.52     21.06  ...       310        NaN
#
#    clouds_all          dt  country     sunrise      sunset  timezone  city_id  \
# 0          34  1764129959       VN  1764112440  1764152047     25200  1581130
# 1          99  1764130392       PH  1764107427  1764150107     28800  1687343
# 2          70  1764130173       VN  1764112135  1764151758     25200  1580410
# 3          49  1764130211       VN  1764112316  1764151943     25200  1581326
# 4          75  1764130121       VN  1764111554  1764152089     25200  1580240
#
#              city_name
# 0               Hà Nội
# 1                 Sapa
# 2    Thành Phố Hạ Long
# 3  Thành Phố Hải Dương
# 4                  Huế
#
# [5 rows x 25 columns]
# /tmp/ipykernel_28112/2654568134.py:68: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_current = pd.concat([fetch_weather(c) for c in cities if fetch_weather(c) is not None], ignore_index=True)

# %%
def fetch_forecast(city):
    url = f"https://api.openweathermap.org/data/2.5/forecast?q={city}&appid={API_KEY}&units=metric&lang=vi"

    response = requests.get(url)
    data = response.json()
    return data

# Loop through each city and print weather
for c in cities:
    result = fetch_forecast(c)
    print(f"\n=== {c} ===")
    print(result)
# Out:
# === Hanoi ===
# {'cod': '200', 'message': 0, 'cnt': 40, 'list': [{'dt': 1764136800, 'main': {'temp': 22.62, 'feels_like': 21.93, 'temp_min': 22.62, 'temp_max': 23.87, 'pressure': 1021, 'sea_level': 1021, 'grnd_level': 1018, 'humidity': 38, 'temp_kf': -1.25}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'mây rải rác', 'icon': '03d'}], 'clouds': {'all': 26}, 'wind': {'speed': 3.31, 'deg': 354, 'gust': 4.41}, 'visibility': 10000, 'pop': 0, 'sys': {'pod': 'd'}, 'dt_txt': '2025-11-26 06:00:00'}, {'dt': 1764147600, 'main': {'temp': 23.45, 'feels_like': 22.74, 'temp_min': 23.45, 'temp_max': 24.17, 'pressure': 1019, 'sea_level': 1019, 'grnd_level': 1017, 'humidity': 34, 'temp_kf': -0.72}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'mây rải rác', 'icon': '03d'}], 'clouds': {'all': 38}, 'wind': {'speed': 2.42, 'deg': 19, 'gust': 4.11}, 'visibility': 10000, 'pop': 0, 'sys': {'pod': 'd'}, 'dt_txt': '2025-11-26 09:00:00'}, {'dt': 1764158400, 'main': {'temp': 20, 'feels_like': 19.18, 'temp_min': 20, 'temp_max': 20, 'pressure': 1022, 'sea_level': 1022, 'grnd_level': 1021, 'humidity': 43, 'temp_kf': 0}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'mây rải rác', 'icon': '03n'}], 'clouds': {'all': 31}, 'wind': {'speed': 2.75, 'deg': 38, 'gust': 6.41}, 'visibility': 10000, 'pop': 0, 'sys': {'pod': 'n'}, 'dt_txt': '2025-11-26 12:00:00'}, {'dt': 1764169200, 'main': {'temp': 17.88, 'feels_like': 17, 'temp_min': 17.88, 'temp_max': 17.88, 'pressure': 1024, 'sea_level': 1024, 'grnd_level': 1024, 'humidity': 49, 'temp_kf': 0}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'bầu trời quang đãng', 'icon': '01n'}], 'clouds': {'all': 6}, 'wind': {'speed': 3.05, 'deg': 19, 'gust': 5.03}, 'visibility': 10000, 'pop': 0, 'sys': {'pod': 'n'}, 'dt_txt': '2025-11-26 15:00:00'}, {'dt': 1764180000, 'main': {'temp': 16.99, 'feels_like': 16.15, 'temp_min': 16.99, 'temp_max': 16.99, 'pressure': 1024, 'sea_level': 1024, 'grnd_level': 1023, 'humidity': 54, 'temp_kf': 0}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'bầu trời quang đãng', 'icon': '01n'}], 'clouds': {'all': 8}, 'wind': {'speed': 3.44, 'deg': 339, 'gust': 7.39}, 'visibility': 10000, 'pop': 0, 'sys': {'pod': 'n'}, 'dt_txt': '2025-11-26 18:00:00'}, {'dt': 1764190800, 'main': {'temp': 15.29, 'feels_like': 14.65, 'temp_min': 15.29, 'temp_max': 15.29, 'pressure': 1023, 'sea_level': 1023, 'grnd_level': 1022, 'humidity': 68, 'temp_kf': 0}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'bầu trời quang đãng', 'icon': '01n'}], 'clouds': {'all': 10}, 'wind': {'speed': 3.28, 'deg': 327, 'gust': 7.46}, 'visibility': 10000, 'pop': 0, 'sys': {'pod': 'n'}, 'dt_txt': '2025-11-26 21:00:00'}, {'dt': 1764201600, 'main': {'temp': 15.49, 'feels_like': 14.79, 'temp_min': 15.49, 'temp_max': 15.49, 'pressure': 1026, 'sea_level': 1026, 'grnd_level': 1025, 'humidity': 65, 'temp_kf': 0}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'mây rải rác', 'icon': '03d'}], 'clouds': {'all': 32}, 'wind': {'speed': 2.4, 'deg': 346, 'gust': 8}, 'visibility': 10000, 'pop': 0, 'sys': {'pod': 'd'}, 'dt_txt': '2025-11-27 00:00:00'}, {'dt': 1764212400, 'main': {'temp': 21.98, 'feels_like': 21.04, 'temp_min': 21.98, 'temp_max': 21.98, 'pressure': 1026, 'sea_level': 1026, 'grnd_level': 1026, 'humidity': 31, 'temp_kf': 0}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'mây thưa', 'icon': '02d'}], 'clouds': {'all': 14}, 'wind': {'speed': 8.14, 'deg': 17, 'gust': 12.3}, 'visibility': 10000, 'pop': 0, 'sys': {'pod': 'd'}, 'dt_txt': '2025-11-27 03:00:00'}, {'dt': 1764223200, 'main': {'temp':
, 'visibility': 10000, 'pop': 0, 'sys': {'pod': 'n'}, 'dt_txt': '2025-11-26 21:00:00'}, {'dt': 1764201600, 'main': {'temp': 21.01, 'feels_like': 21.23, 'temp_min': 21.01, 'temp_max': 21.01, 'pressure': 1011, 'sea_level': 1011, 'grnd_level': 1011, 'humidity': 79, 'temp_kf': 0}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'mây đen u ám', 'icon': '04d'}], 'clouds': {'all': 100}, 'wind': {'speed': 5, 'deg': 360, 'gust': 13.47}, 'visibility': 10000, 'pop': 0, 'sys': {'pod': 'd'}, 'dt_txt': '2025-11-27 00:00:00'}, {'dt': 1764212400, 'main': {'temp': 25.98, 'feels_like': 25.98, 'temp_min': 25.98, 'temp_max': 25.98, 'pressure': 1011, 'sea_level': 1011, 'grnd_level': 1011, 'humidity': 63, 'temp_kf': 0}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'mây đen u ám', 'icon': '04d'}], 'clouds': {'all': 94}, 'wind': {'speed': 6.78, 'deg': 15, 'gust': 9.52}, 'visibility': 10000, 'pop': 0, 'sys': {'pod': 'd'}, 'dt_txt': '2025-11-27 03:00:00'}, {'dt': 1764223200, 'main': {'temp': 27.37, 'feels_like': 28.74, 'temp_min': 27.37, 'temp_max': 27.37, 'pressure': 1009, 'sea_level': 1009, 'grnd_level': 1009, 'humidity': 62, 'temp_kf': 0}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'mây đen u ám', 'icon': '04d'}], 'clouds': {'all': 97}, 'wind': {'speed': 5.99, 'deg': 24, 'gust': 7.01}, 'visibility': 10000, 'pop': 0, 'sys': {'pod': 'd'}, 'dt_txt': '2025-11-27 06:00:00'}, {'dt': 1 ...
#
# === Vinh Long ===
# {'cod': '200', 'message': 0, 'cnt': 40, 'list': [{'dt': 1764136800, 'main': {'temp': 27.81, 'feels_like': 29.83, 'temp_min': 27.81, 'temp_max': 29.03, 'pressure': 1010, 'sea_level': 1010, 'grnd_level': 1009, 'humidity': 66, 'temp_kf': -1.22}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'mây đen u ám', 'icon': '04d'}], 'clouds': {'all': 100}, 'wind': {'speed': 3.09, 'deg': 339, 'gust': 3.07}, 'visibility': 10000, 'pop': 0, 'sys': {'pod': 'd'}, 'dt_txt': '2025-11-26 06:00:00'}, {'dt': 1764147600, 'main': {'temp': 28.91, 'feels_like': 31.83, 'temp_min': 28.91, 'temp_max': 29.76, 'pressure': 1009, 'sea_level': 1009, 'grnd_level': 1008, 'humidity': 66, 'temp_kf': -0.85}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'mây đen u ám', 'icon': '04d'}], 'clouds': {'all': 96}, 'wind': {'speed': 3.1, 'deg': 350, 'gust': 4.06}, 'visibility': 10000, 'pop': 0, 'sys': {'pod': 'd'}, 'dt_txt': '2025-11-26 09:00:00'}, {'dt': 1764158400, 'main': {'temp': 26.28, 'feels_like': 26.28, 'temp_min': 26.28, 'temp_max': 26.28, 'pressure': 1011, 'sea_level': 1011, 'grnd_level': 1010, 'humidity': 74, 'temp_kf': 0}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'mây cụm', 'icon': '04n'}], 'clouds': {'all': 68}, 'wind': {'speed': 1.68, 'deg': 292, 'gust': 1.75}, 'visibility': 10000, 'pop': 0, 'sys': {'pod': 'n'}, 'dt_txt': '2025-11-26 12:00:00'}, {'dt': 1764169200, 'main': {'temp': 24.48, 'feels_like': 25.07, 'temp_min': 24.48, 'temp_max': 24.48, 'pressure': 1012, 'sea_level': 1012, 'grnd_level': 1012, 'humidity': 80, 'temp_kf': 0}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'mây đen u ám', 'icon': '04n'}], 'clouds': {'all': 92}, 'wind': {'speed': 3.57, 'deg': 350, 'gust': 10.1}, 'visibility': 10000, 'pop': 0, 'sys': {'pod': 'n'}, 'dt_txt': '2025-11-26 15:00:00'}, {'dt': 1764180000, 'main': {'temp': 23.06, 'feels_like': 23.51, 'temp_min': 23.06, 'temp_max': 23.06, 'pressure': 1011, 'sea_level': 1011, 'grnd_level': 1010, 'humidity': 80, 'temp_kf': 0}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'mây cụm', 'icon': '04n'}], 'clouds': {'all': 63}, 'wind': {'speed': 3.4, 'deg': 342, 'gust': 10.06}, 'visibility': 10000, 'pop': 0, 'sys': {'pod': 'n'}, 'dt_txt': '2025-11-26 18:00:00'}, {'dt': 1764190800, 'main': {'temp': 20.84, 'feels_like': 21.04, 'temp_min': 20.84, 'temp_max': 20.84, 'pressure': 1010, 'sea_level': 1010, 'grnd_level': 1009, 'humidity': 79, 'temp_kf': 0}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'mây đen u ám', 'icon': '04n'}], 'clouds': {'all': 100}, 'wind': {'speed': 4.18, 'deg': 348, 'gust': 10.66}, 'visibility': 10000, 'pop': 0, 'sys': {'pod': 'n'}, 'dt_txt': '2025-11-26 21:00:00'}, {'dt': 1764201600, 'main': {'temp': 20.63, 'feels_like': 20.81, 'temp_min': 20.63, 'temp_max': 20.63, 'pressure': 1011, 'sea_level': 1011, 'grnd_level': 1011, 'humidity': 79, 'temp_kf': 0}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'mây đen u ám', 'icon': '04d'}], 'clouds': {'all': 100}, 'wind': {'speed': 4.53, 'deg': 355, 'gust': 13}, 'visibility': 10000, 'pop': 0, 'sys': {'pod': 'd'}, 'dt_txt': '2025-11-27 00:00:00'}, {'dt': 1764212400, 'main': {'temp': 25.38, 'feels_like': 25.67, 'temp_min': 25.38, 'temp_max': 25.38, 'pressure': 1011, 'sea_level': 1011, 'grnd_level': 1011, 'humidity': 65, 'temp_kf': 0}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'mây đen u ám', 'icon': '04d'}], 'clouds': {'all': 100}, 'wind': {'speed': 6.38, 'deg': 14, 'gust': 8.56}, 'visibility': 10000, 'pop': 0, 'sys': {'pod': 'd'}, 'dt_txt': '2025-11-27 03:00:00'}, {'dt': 1764223200, 'main': {'temp': 27.69, 'feels_like': 29.1, 'temp_min': 27.69, 'temp_max': 27.69, 'pressure': 1009, 'sea_level': 1009, 'grnd_level': 1009, 'humidity': 61, 'temp_kf': 0}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'mây đen u ám', 'icon': '04d'}], 'clouds': {'all': 100}, 'wind': {'speed': 5.45, 'deg': 16, 'gust': 6.53}, 'visibility': 10000, 'pop': 0, 'sys': {'pod': 'd'}, 'dt_txt': '2025-11-27 06:00 ...

# %%
import pandas as pd
def fetch_forecast(city):
    url = f"https://api.openweathermap.org/data/2.5/forecast?q={city}&appid={API_KEY}&units=metric&lang=vi"
    response = requests.get(url)
    data = response.json()
    rows = []

    for item in data['list']:
        row = {
        'dt': item['dt'],
        'dt_txt': item['dt_txt'],
        'temp': item['main']['temp'],
        'feels_like': item['main']['feels_like'],
        'temp_min': item['main']['temp_min'],
        'temp_max': item['main']['temp_max'],
        'pressure': item['main']['pressure'],
        'sea_level': item['main'].get('sea_level'),
        'grnd_level': item['main'].get('grnd_level'),
        'humidity': item['main']['humidity'],
        'temp_kf': item['main'].get('temp_kf'),
        'weather_id': item['weather'][0]['id'],
        'weather_main': item['weather'][0]['main'],
        'description': item['weather'][0]['description'],
        'weather_icon': item['weather'][0]['icon'],
        'clouds_all': item['clouds']['all'],
        'wind_speed': item['wind']['speed'],
        'wind_deg': item['wind']['deg'],
        'wind_gust': item['wind'].get('gust'),
        'visibility': item.get('visibility'),
        'pop': item.get('pop'),
        'sys_pod': item['sys'].get('pod'),
        'city_id': data['city']['id'],
        'city_name': data['city']['name'],
        'country': data['city']['country'],
        'coord_lat': data['city']['coord']['lat'],
        'coord_lon': data['city']['coord']['lon'],
        'population': data['city'].get('population'),
        'timezone': data['city'].get('timezone'),
        'sunrise': data['city'].get('sunrise'),
        'sunset': data['city'].get('sunset')
    }
        rows.append(row)
    df_forecast = pd.DataFrame(rows)

    return df_forecast

# Loop through each city and print weather
df_forecasts = pd.concat([fetch_forecast(c) for c in cities], ignore_index=True)

print(df_forecasts.head())
# Out:
#            dt               dt_txt   temp  feels_like  temp_min  temp_max  \
# 0  1764136800  2025-11-26 06:00:00  22.62       21.93     22.62     23.87
# 1  1764147600  2025-11-26 09:00:00  23.45       22.74     23.45     24.17
# 2  1764158400  2025-11-26 12:00:00  20.00       19.18     20.00     20.00
# 3  1764169200  2025-11-26 15:00:00  17.88       17.00     17.88     17.88
# 4  1764180000  2025-11-26 18:00:00  16.99       16.15     16.99     16.99
#
#    pressure  sea_level  grnd_level  humidity  ...  sys_pod  city_id city_name  \
# 0      1021       1021        1018        38  ...        d  1581130    Hà Nội
# 1      1019       1019        1017        34  ...        d  1581130    Hà Nội
# 2      1022       1022        1021        43  ...        n  1581130    Hà Nội
# 3      1024       1024        1024        49  ...        n  1581130    Hà Nội
# 4      1024       1024        1023        54  ...        n  1581130    Hà Nội
#
#   country coord_lat  coord_lon  population  timezone     sunrise      sunset
# 0      VN   21.0245   105.8412     1431270     25200  1764112440  1764152047
# 1      VN   21.0245   105.8412     1431270     25200  1764112440  1764152047
# 2      VN   21.0245   105.8412     1431270     25200  1764112440  1764152047
# 3      VN   21.0245   105.8412     1431270     25200  1764112440  1764152047
# 4      VN   21.0245   105.8412     1431270     25200  1764112440  1764152047
#
# [5 rows x 31 columns]

# %% [markdown]
# ## **Transform data**

# %%
#process time column
from datetime import datetime
# Convert UNIX timestamps for current weather
df_current["dt"] = pd.to_datetime(df_current["dt"], unit="s")
df_current["sunrise"] = pd.to_datetime(df_current["sunrise"], unit="s")
df_current["sunset"] = pd.to_datetime(df_current["sunset"], unit="s")

# Convert UNIX timestamps for forecast weather
df_forecasts["dt"] = pd.to_datetime(df_forecasts["dt"], unit="s")
df_forecasts["sunrise"] = pd.to_datetime(df_forecasts["sunrise"], unit="s")
df_forecasts["sunset"] = pd.to_datetime(df_forecasts["sunset"], unit="s")

# Display columns
print(df_current[["dt", "sunrise", "sunset"]].head())
print(df_forecasts[["dt", "sunrise", "sunset"]].head())
# Out:
#                    dt             sunrise              sunset
# 0 2025-11-26 04:05:59 2025-11-25 23:14:00 2025-11-26 10:14:07
# 1 2025-11-26 04:13:12 2025-11-25 21:50:27 2025-11-26 09:41:47
# 2 2025-11-26 04:09:33 2025-11-25 23:08:55 2025-11-26 10:09:18
# 3 2025-11-26 04:10:11 2025-11-25 23:11:56 2025-11-26 10:12:23
# 4 2025-11-26 04:08:41 2025-11-25 22:59:14 2025-11-26 10:14:49
#                    dt             sunrise              sunset
# 0 2025-11-26 06:00:00 2025-11-25 23:14:00 2025-11-26 10:14:07
# 1 2025-11-26 09:00:00 2025-11-25 23:14:00 2025-11-26 10:14:07
# 2 2025-11-26 12:00:00 2025-11-25 23:14:00 2025-11-26 10:14:07
# 3 2025-11-26 15:00:00 2025-11-25 23:14:00 2025-11-26 10:14:07
# 4 2025-11-26 18:00:00 2025-11-25 23:14:00 2025-11-26 10:14:07

# %%
df_current["dt"] = df_current["dt"].dt.tz_localize("UTC").dt.tz_convert("Asia/Ho_Chi_Minh")
df_current["sunrise"] = df_current["sunrise"].dt.tz_localize("UTC").dt.tz_convert("Asia/Ho_Chi_Minh")
df_current["sunset"] = df_current["sunset"].dt.tz_localize("UTC").dt.tz_convert("Asia/Ho_Chi_Minh")
print(df_current[["dt", "sunrise", "sunset"]].head())
# Out:
#                          dt                   sunrise  \
# 0 2025-11-26 11:05:59+07:00 2025-11-26 06:14:00+07:00
# 1 2025-11-26 11:13:12+07:00 2025-11-26 04:50:27+07:00
# 2 2025-11-26 11:09:33+07:00 2025-11-26 06:08:55+07:00
# 3 2025-11-26 11:10:11+07:00 2025-11-26 06:11:56+07:00
# 4 2025-11-26 11:08:41+07:00 2025-11-26 05:59:14+07:00
#
#                      sunset
# 0 2025-11-26 17:14:07+07:00
# 1 2025-11-26 16:41:47+07:00
# 2 2025-11-26 17:09:18+07:00
# 3 2025-11-26 17:12:23+07:00
# 4 2025-11-26 17:14:49+07:00

# %%
df_forecasts["dt"] = df_forecasts["dt"].dt.tz_localize("UTC").dt.tz_convert("Asia/Ho_Chi_Minh")
df_forecasts["sunrise"] = df_forecasts["sunrise"].dt.tz_localize("UTC").dt.tz_convert("Asia/Ho_Chi_Minh")
df_forecasts["sunset"] = df_forecasts["sunset"].dt.tz_localize("UTC").dt.tz_convert("Asia/Ho_Chi_Minh")
print(df_forecasts[["dt", "sunrise", "sunset"]].head())
# Out:
#                          dt                   sunrise  \
# 0 2025-11-26 13:00:00+07:00 2025-11-26 06:14:00+07:00
# 1 2025-11-26 16:00:00+07:00 2025-11-26 06:14:00+07:00
# 2 2025-11-26 19:00:00+07:00 2025-11-26 06:14:00+07:00
# 3 2025-11-26 22:00:00+07:00 2025-11-26 06:14:00+07:00
# 4 2025-11-27 01:00:00+07:00 2025-11-26 06:14:00+07:00
#
#                      sunset
# 0 2025-11-26 17:14:07+07:00
# 1 2025-11-26 17:14:07+07:00
# 2 2025-11-26 17:14:07+07:00
# 3 2025-11-26 17:14:07+07:00
# 4 2025-11-26 17:14:07+07:00

# %% [markdown]
# ## **Load data**

# %%
import sqlalchemy
print(sqlalchemy.__version__)
# Out:
# 1.4.54

# %%
from sqlalchemy import create_engine
import psycopg2

conn = psycopg2.connect(
    dbname="weather_data",
    user="postgres",     # change if needed
    password="050701",  # change
    host="localhost",
    port=5432
)

cursor = conn.cursor()

# %%
df_cities = df_current[["city_id", "city_name", "country", "coord_lat", "coord_lon", "timezone"]].drop_duplicates()

insert_query = """
    INSERT INTO cities (city_id, city_name, country, coord_lat, coord_lon, timezone)
    VALUES (%s, %s, %s, %s, %s, %s)
    ON CONFLICT (city_id) DO NOTHING  -- optional if city_id is PK to avoid duplicates
"""

for row in df_cities.itertuples(index=False):
    cursor.execute(insert_query, row)

conn.commit()

# %%
except_column = ["city_name", "country", "coord_lat", "coord_lon", "timezone", "population"]

df_current = df_current[[col for col in df_current.columns if col not in except_column]]
df_current.head()
# Out:
#    weather_id weather_main  description weather_icon      base   temp  \
# 0         802       Clouds  mây rải rác          03d  stations  22.00
# 1         500         Rain      mưa nhẹ          10d  stations  29.55
# 2         803       Clouds      mây cụm          04d  stations  23.25
# 3         802       Clouds  mây rải rác          03d  stations  23.56
# 4         803       Clouds      mây cụm          04d  stations  21.06
#
#    feels_like  temp_min  temp_max  pressure  humidity  visibility  wind_speed  \
# 0       21.22     22.00     22.00      1021        37       10000        4.12
# 1       34.41     29.55     29.55      1007        72       10000        4.69
# 2       22.62     23.25     23.25      1020        38       10000        0.99
# 3       22.96     23.56     23.56      1021        38       10000        4.13
# 4       21.52     21.06     21.06      1018        88       10000        5.14
#
#    wind_deg  wind_gust  clouds_all                        dt  \
# 0       355       5.89          34 2025-11-26 11:05:59+07:00
# 1       186       6.43          99 2025-11-26 11:13:12+07:00
# 2       140       0.87          70 2025-11-26 11:09:33+07:00
# 3         1       4.43          49 2025-11-26 11:10:11+07:00
# 4       310        NaN          75 2025-11-26 11:08:41+07:00
#
#                     sunrise                    sunset  city_id
# 0 2025-11-26 06:14:00+07:00 2025-11-26 17:14:07+07:00  1581130
# 1 2025-11-26 04:50:27+07:00 2025-11-26 16:41:47+07:00  1687343
# 2 2025-11-26 06:08:55+07:00 2025-11-26 17:09:18+07:00  1580410
# 3 2025-11-26 06:11:56+07:00 2025-11-26 17:12:23+07:00  1581326
# 4 2025-11-26 05:59:14+07:00 2025-11-26 17:14:49+07:00  1580240

# %%
df_current.columns
# Out:
# Index(['weather_id', 'weather_main', 'description', 'weather_icon', 'base',
#        'temp', 'feels_like', 'temp_min', 'temp_max', 'pressure', 'humidity',
#        'visibility', 'wind_speed', 'wind_deg', 'wind_gust', 'clouds_all', 'dt',
#        'sunrise', 'sunset', 'city_id'],
#       dtype='object')

# %%
df_forecasts = df_forecasts[[col for col in df_forecasts.columns if col not in except_column]]
df_forecasts.head()
# Out:
#                          dt               dt_txt   temp  feels_like  temp_min  \
# 0 2025-11-26 13:00:00+07:00  2025-11-26 06:00:00  22.62       21.93     22.62
# 1 2025-11-26 16:00:00+07:00  2025-11-26 09:00:00  23.45       22.74     23.45
# 2 2025-11-26 19:00:00+07:00  2025-11-26 12:00:00  20.00       19.18     20.00
# 3 2025-11-26 22:00:00+07:00  2025-11-26 15:00:00  17.88       17.00     17.88
# 4 2025-11-27 01:00:00+07:00  2025-11-26 18:00:00  16.99       16.15     16.99
#
#    temp_max  pressure  sea_level  grnd_level  humidity  ...  clouds_all  \
# 0     23.87      1021       1021        1018        38  ...          26
# 1     24.17      1019       1019        1017        34  ...          38
# 2     20.00      1022       1022        1021        43  ...          31
# 3     17.88      1024       1024        1024        49  ...           6
# 4     16.99      1024       1024        1023        54  ...           8
#
#    wind_speed wind_deg wind_gust visibility  pop  sys_pod  city_id  \
# 0        3.31      354      4.41      10000  0.0        d  1581130
# 1        2.42       19      4.11      10000  0.0        d  1581130
# 2        2.75       38      6.41      10000  0.0        n  1581130
# 3        3.05       19      5.03      10000  0.0        n  1581130
# 4        3.44      339      7.39      10000  0.0        n  1581130
#
#                     sunrise                    sunset
# 0 2025-11-26 06:14:00+07:00 2025-11-26 17:14:07+07:00
# 1 2025-11-26 06:14:00+07:00 2025-11-26 17:14:07+07:00
# 2 2025-11-26 06:14:00+07:00 2025-11-26 17:14:07+07:00
# 3 2025-11-26 06:14:00+07:00 2025-11-26 17:14:07+07:00
# 4 2025-11-26 06:14:00+07:00 2025-11-26 17:14:07+07:00
#
# [5 rows x 25 columns]

# %%
df_forecasts.columns
# Out:
# Index(['dt', 'dt_txt', 'temp', 'feels_like', 'temp_min', 'temp_max',
#        'pressure', 'sea_level', 'grnd_level', 'humidity', 'temp_kf',
#        'weather_id', 'weather_main', 'description', 'weather_icon',
#        'clouds_all', 'wind_speed', 'wind_deg', 'wind_gust', 'visibility',
#        'pop', 'sys_pod', 'city_id', 'sunrise', 'sunset'],
#       dtype='object')

# %%
# Load current weather
insert_query = """
INSERT INTO current_weather (
    weather_id, weather_main, description, base,
    temp, feels_like, temp_min, temp_max, pressure, humidity,
    visibility, wind_speed, wind_deg, wind_gust, clouds_all, dt,
    sunrise, sunset, city_id
) VALUES (
    # %s, %s, %s, %s,
    # %s, %s, %s, %s, %s, %s,
    # %s, %s, %s, %s, %s, %s,
    # %s, %s, %s
)

"""

columns_order = [
    'weather_id', 'weather_main', 'description', 'base',
    'temp', 'feels_like', 'temp_min', 'temp_max', 'pressure', 'humidity',
    'visibility', 'wind_speed', 'wind_deg', 'wind_gust', 'clouds_all', 'dt',
    'sunrise', 'sunset', 'city_id'
]

df_current_ordered = df_current[columns_order]

try:
    for row in df_current_ordered.itertuples(index=False):
        cursor.execute(insert_query, row)
    conn.commit()  # commit all successful inserts
except Exception as e:
    print(f"Transaction failed: {e}")
    conn.rollback()  # rollback everything

# %%
# Load current weather
insert_query = """
INSERT INTO forecast_weather (
    dt, dt_txt, temp, feels_like, temp_min, temp_max,
       pressure, humidity,
       weather_id, weather_main, description,
       wind_speed, wind_deg, wind_gust, visibility,
        city_id, sunrise, sunset
) VALUES (
    # %s, %s, %s, 
    # %s, %s, %s, %s, %s, %s,
    # %s, %s, %s, %s, %s, %s,
    # %s, %s, %s
)

"""

columns_order = [
    'dt', 'dt_txt', 'temp', 'feels_like', 'temp_min', 'temp_max',
       'pressure', 'humidity',
       'weather_id', 'weather_main', 'description',
       'wind_speed', 'wind_deg', 'wind_gust', 'visibility',
        'city_id', 'sunrise', 'sunset'
]

df_current_ordered = df_forecasts[columns_order]

try:
    for row in df_current_ordered.itertuples(index=False):
        cursor.execute(insert_query, row)
    conn.commit()  # commit all successful inserts
except Exception as e:
    print(f"Transaction failed: {e}")
    conn.rollback()  # rollback everything

# %%
cursor.close()
conn.close()

# %% [markdown]
# **END.**
